# %%
! pip install anyio==3.6.2
! pip install appnope==0.1.3
! pip install argon2-cffi==21.3.0
! pip install argon2-cffi-bindings==21.2.0
! pip install arrow==1.2.3
! pip install asttokens==2.2.1
! pip install attrs==23.1.0
! pip install backcall==0.2.0
! pip install beautifulsoup4==4.12.2
! pip install bleach==6.0.0
! pip install cffi==1.15.1
! pip install comm==0.1.3
! pip install debugpy==1.6.7
! pip install decorator==5.1.1
! pip install defusedxml==0.7.1
! pip install executing==1.2.0
! pip install fastjsonschema==2.16.3
! pip install fqdn==1.5.1
! pip install idna==3.4
! pip install ipykernel==6.23.0
! pip install ipython==8.13.2
! pip install ipython-genutils==0.2.0
! pip install ipywidgets==8.0.6
! pip install isoduration==20.11.0
! pip install jedi==0.18.2
! pip install Jinja2==3.1.2
! pip install jsonpointer==2.3
! pip install jsonschema==4.17.3
! pip install jupyter==1.0.0
! pip install jupyter_client==8.2.0
! pip install jupyter-console==6.6.3
! pip install jupyter_core==5.3.0
! pip install jupyter-events==0.6.3
! pip install jupyter_server==2.5.0
! pip install jupyter_server_terminals==0.4.4
! pip install jupyterlab-pygments==0.2.2
! pip install jupyterlab-widgets==3.0.7
! pip install MarkupSafe==2.1.2
! pip install matplotlib-inline==0.1.6
! pip install mistune==2.0.5
! pip install nbclassic==1.0.0
! pip install nbclient==0.7.4
! pip install nbconvert==7.4.0
! pip install nbformat==5.8.0
! pip install nest-asyncio==1.5.6
! pip install notebook==6.5.4
! pip install notebook_shim==0.2.3
! pip install packaging==23.1
! pip install pandocfilters==1.5.0
! pip install parso==0.8.3
! pip install pexpect==4.8.0
! pip install pickleshare==0.7.5
! pip install pip==23.0.1
! pip install platformdirs==3.5.0
! pip install prometheus-client==0.16.0
! pip install prompt-toolkit==3.0.38
! pip install psutil==5.9.5
! pip install ptyprocess==0.7.0
! pip install pure-eval==0.2.2
! pip install pycparser==2.21
! pip install Pygments==2.15.1
! pip install pyrsistent==0.19.3
! pip install python-dateutil==2.8.2
! pip install python-json-logger==2.0.7
! pip install PyYAML==6
! pip install pyzmq==25.0.2
! pip install qtconsole==5.4.3
! pip install QtPy==2.3.1
! pip install rfc3339-validator==0.1.4
! pip install rfc3986-validator==0.1.1
! pip install Send2Trash==1.8.2
! pip install setuptools==67.6.1
! pip install six==1.16.0
! pip install sniffio==1.3.0
! pip install soupsieve==2.4.1
! pip install stack-data==0.6.2
! pip install terminado==0.17.1
! pip install tinycss2==1.2.1
! pip install tornado==6.3.1
! pip install traitlets==5.9.0
! pip install typing_extensions==4.6.3
! pip install uri-template==1.2.0
! pip install wcwidth==0.2.6
! pip install webcolors==1.13
! pip install webencodings==0.5.1
! pip install websocket-client==1.5.1
! pip install wheel==0.40.0
! pip install widgetsnbextension==4.0.7
# Out:
# Collecting anyio==3.6.2
#   Using cached anyio-3.6.2-py3-none-any.whl (80 kB)
# Collecting idna>=2.8
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Installing collected packages: sniffio, idna, anyio
# Successfully installed anyio-3.6.2 idna-3.4 sniffio-1.3.0
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: appnope==0.1.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (0.1.3)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting argon2-cffi==21.3.0
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Collecting cffi>=1.0.1
#   Using cached cffi-1.15.1-cp39-cp39-macosx_11_0_arm64.whl (174 kB)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Installing collected packages: pycparser, cffi, argon2-cffi-bindings, argon2-cffi
# Successfully installed argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 cffi-1.15.1 pycparser-2.21
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from argon2-cffi-bindings==21.2.0) (1.15.1)
# Requirement already satisfied: pycparser in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings==21.2.0) (2.21)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting arrow==1.2.3
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from arrow==1.2.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from python-dateutil>=2.7.0->arrow==1.2.3) (1.16.0)
# Installing collected packages: arrow
# Successfully installed arrow-1.2.3
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: asttokens==2.2.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: six in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from asttokens==2.2.1) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting attrs==23.1.0
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Installing collected packages: attrs
# Successfully installed attrs-23.1.0
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: backcall==0.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (0.2.0)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting beautifulsoup4==4.12.2
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.2 soupsieve-2.4.1
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting bleach==6.0.0
#   Using cached bleach-6.0.0-py3-none-any.whl (162 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.9.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from bleach==6.0.0) (1.16.0)
# Installing collected packages: webencodings, bleach
# Successfully installed bleach-6.0.0 webencodings-0.5.1
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: cffi==1.15.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (1.15.1)
# Requirement already satisfied: pycparser in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from cffi==1.15.1) (2.21)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: comm==0.1.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (0.1.3)
# Requirement already satisfied: traitlets>=5.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from comm==0.1.3) (5.9.0)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: debugpy==1.6.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (1.6.7)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: decorator==5.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (5.1.1)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting defusedxml==0.7.1
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: defusedxml
# Successfully installed defusedxml-0.7.1
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: executing==1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (1.2.0)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting fastjsonschema==2.16.3
#   Using cached fastjsonschema-2.16.3-py3-none-any.whl (23 kB)
# Installing collected packages: fastjsonschema
# Successfully installed fastjsonschema-2.16.3
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting fqdn==1.5.1
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Installing collected packages: fqdn
# Successfully installed fqdn-1.5.1
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: idna==3.4 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (3.4)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting ipykernel==6.23.0
#   Using cached ipykernel-6.23.0-py3-none-any.whl (150 kB)
# Requirement already satisfied: appnope in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (0.1.3)
# Requirement already satisfied: psutil in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (5.9.5)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (8.14.0)
# Requirement already satisfied: comm>=0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (0.1.3)
# Requirement already satisfied: packaging in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (23.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (5.3.1)
# Requirement already satisfied: pyzmq>=20 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (25.1.0)
# Requirement already satisfied: nest-asyncio in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (1.5.6)
# Requirement already satisfied: tornado>=6.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel==6.23.0) (8.2.0)
# Requirement already satisfied: backcall in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (4.8.0)
# Requirement already satisfied: stack-data in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (0.6.2)
# Requirement already satisfied: decorator in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (2.15.1)
# Requirement already satisfied: jedi>=0.16 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (0.7.5)
# Requirement already satisfied: typing-extensions in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (4.6.3)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (3.0.38)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.23.0) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel==6.23.0) (2.8.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel==6.23.0) (6.7.0)
# Requirement already satisfied: zipp>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel==6.23.0) (3.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.23.0) (3.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.23.0) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel==6.23.0) (0.2.6)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel==6.23.0) (1.16.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.23.0) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.23.0) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.23.0) (1.2.0)
# Installing collected packages: ipykernel
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.23.2
#     Uninstalling ipykernel-6.23.2:
#       Successfully uninstalled ipykernel-6.23.2
# Successfully installed ipykernel-6.23.0
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting ipython==8.13.2
#   Using cached ipython-8.13.2-py3-none-any.whl (797 kB)
# Requirement already satisfied: typing-extensions in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (4.6.3)
# Requirement already satisfied: matplotlib-inline in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (0.1.6)
# Requirement already satisfied: decorator in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (3.0.38)
# Requirement already satisfied: appnope in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (0.1.3)
# Requirement already satisfied: pygments>=2.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (2.15.1)
# Requirement already satisfied: jedi>=0.16 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (0.7.5)
# Requirement already satisfied: stack-data in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (0.6.2)
# Requirement already satisfied: backcall in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (4.8.0)
# Requirement already satisfied: traitlets>=5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython==8.13.2) (5.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jedi>=0.16->ipython==8.13.2) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from pexpect>4.3->ipython==8.13.2) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.13.2) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython==8.13.2) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython==8.13.2) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython==8.13.2) (2.2.1)
# Requirement already satisfied: six in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data->ipython==8.13.2) (1.16.0)
# Installing collected packages: ipython
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.14.0
#     Uninstalling ipython-8.14.0:
#       Successfully uninstalled ipython-8.14.0
# Successfully installed ipython-8.13.2
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting ipython-genutils==0.2.0
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Installing collected packages: ipython-genutils
# Successfully installed ipython-genutils-0.2.0
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting ipywidgets==8.0.6
#   Using cached ipywidgets-8.0.6-py3-none-any.whl (138 kB)
# Collecting jupyterlab-widgets~=3.0.7
#   Using cached jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
# Collecting widgetsnbextension~=4.0.7
#   Using cached widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipywidgets==8.0.6) (6.23.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipywidgets==8.0.6) (5.9.0)
# Requirement already satisfied: ipython>=6.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipywidgets==8.0.6) (8.13.2)
# Requirement already satisfied: tornado>=6.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (6.3.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (8.2.0)
# Requirement already satisfied: appnope in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (0.1.3)
# Requirement already satisfied: pyzmq>=20 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (25.1.0)
# Requirement already satisfied: packaging in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (23.1)
# Requirement already satisfied: psutil in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (5.9.5)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (5.3.1)
# Requirement already satisfied: nest-asyncio in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (1.5.6)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (1.6.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (2.15.1)
# Requirement already satisfied: decorator in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (3.0.38)
# Requirement already satisfied: typing-extensions in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (4.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (4.8.0)
# Requirement already satisfied: backcall in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (0.7.5)
# Requirement already satisfied: stack-data in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (0.6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.0.6) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.6) (2.8.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.6) (6.7.0)
# Requirement already satisfied: zipp>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.6) (3.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==8.0.6) (3.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.0.6) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets==8.0.6) (0.2.6)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.6) (1.16.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.6) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.6) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.6) (0.2.2)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.0.6 jupyterlab-widgets-3.0.7 widgetsnbextension-4.0.7
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting isoduration==20.11.0
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: arrow>=0.15.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from isoduration==20.11.0) (1.2.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration==20.11.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from python-dateutil>=2.7.0->arrow>=0.15.0->isoduration==20.11.0) (1.16.0)
# Installing collected packages: isoduration
# Successfully installed isoduration-20.11.0
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: jedi==0.18.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jedi==0.18.2) (0.8.3)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting Jinja2==3.1.2
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.3-cp39-cp39-macosx_10_9_universal2.whl (17 kB)
# Installing collected packages: MarkupSafe, Jinja2
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.3
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting jsonpointer==2.3
#   Using cached jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Installing collected packages: jsonpointer
# Successfully installed jsonpointer-2.3
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting jsonschema==4.17.3
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Using cached pyrsistent-0.19.3-cp39-cp39-macosx_10_9_universal2.whl (82 kB)
# Requirement already satisfied: attrs>=17.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jsonschema==4.17.3) (23.1.0)
# Installing collected packages: pyrsistent, jsonschema
# Successfully installed jsonschema-4.17.3 pyrsistent-0.19.3
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Collecting jupyter==1.0.0
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: ipywidgets in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter==1.0.0) (8.0.6)
# Collecting notebook
#   Using cached notebook-6.5.4-py3-none-any.whl (529 kB)
# Collecting nbconvert
#   Using cached nbconvert-7.6.0-py3-none-any.whl (290 kB)
# Collecting qtconsole
#   Using cached qtconsole-5.4.3-py3-none-any.whl (121 kB)
# Collecting jupyter-console
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: ipykernel in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter==1.0.0) (6.23.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (8.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (1.6.7)
# Requirement already satisfied: psutil in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (5.9.5)
# Requirement already satisfied: tornado>=6.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (6.3.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (0.1.3)
# Requirement already satisfied: nest-asyncio in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (1.5.6)
# Requirement already satisfied: appnope in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (0.1.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (8.13.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (5.9.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (5.3.1)
# Requirement already satisfied: pyzmq>=20 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (25.1.0)
# Requirement already satisfied: packaging in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (23.1)
# Requirement already satisfied: jedi>=0.16 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.18.2)
# Requirement already satisfied: stack-data in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (4.8.0)
# Requirement already satisfied: typing-extensions in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (4.6.3)
# Requirement already satisfied: pygments>=2.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (2.15.1)
# Requirement already satisfied: decorator in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.7.5)
# Requirement already satisfied: backcall in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (3.0.38)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0) (2.8.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0) (6.7.0)
# Requirement already satisfied: zipp>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0) (3.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0) (3.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.2.6)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0) (1.16.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipywidgets->jupyter==1.0.0) (3.0.7)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipywidgets->jupyter==1.0.0) (4.0.7)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: defusedxml in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (4.12.2)
# Requirement already satisfied: markupsafe>=2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (2.1.3)
# Collecting tinycss2
#   Using cached tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: jinja2>=3.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (3.1.2)
# Collecting nbformat>=5.7
#   Using cached nbformat-5.9.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: bleach!=5.0.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (6.0.0)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.8.0-py3-none-any.whl (73 kB)
# Collecting mistune<4,>=2.0.3
#   Using cached mistune-3.0.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: webencodings in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->jupyter==1.0.0) (0.5.1)
# Requirement already satisfied: fastjsonschema in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0) (4.17.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (23.1.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0) (2.4.1)
# Collecting Send2Trash>=1.8.0
#   Using cached Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting nbclassic>=0.4.7
#   Using cached nbclassic-1.0.0-py3-none-any.whl (10.0 MB)
# Collecting prometheus-client
#   Using cached prometheus_client-0.17.0-py3-none-any.whl (60 kB)
# Requirement already satisfied: ipython-genutils in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (0.2.0)
# Requirement already satisfied: argon2-cffi in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (21.3.0)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting jupyter-server>=1.8
#   Using cached jupyter_server-2.6.0-py3-none-any.whl (375 kB)
# Collecting notebook-shim>=0.2.3
#   Using cached notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Collecting jupyter-events>=0.6.0
#   Using cached jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Collecting websocket-client
#   Using cached websocket_client-1.6.0-py3-none-any.whl (56 kB)
# Collecting jupyter-server-terminals
#   Using cached jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting overrides
#   Using cached overrides-7.3.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: anyio>=3.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (3.6.2)
# Requirement already satisfied: idna>=2.8 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (1.3.0)
# Collecting pyyaml>=5.3
#   Using cached PyYAML-6.0-cp39-cp39-macosx_11_0_arm64.whl (173 kB)
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting rfc3986-validator>=0.1.1
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting webcolors>=1.11
#   Using cached webcolors-1.13-py3-none-any.whl (14 kB)
# Requirement already satisfied: isoduration in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (2.3)
# Requirement already satisfied: fqdn in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (1.5.1)
# Collecting uri-template
#   Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: argon2-cffi-bindings in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter==1.0.0) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0) (1.15.1)
# Requirement already satisfied: pycparser in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (1.2.3)
# Collecting qtpy>=2.0.1
#   Using cached QtPy-2.3.1-py3-none-any.whl (84 kB)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (1.2.0)
# Installing collected packages: webcolors, uri-template, rfc3986-validator, rfc3339-validator, nbformat, tinycss2, terminado, pyyaml, python-json-logger, pandocfilters, nbclient, mistune, jupyterlab-pygments, websocket-client, Send2Trash, prometheus-client, overrides, nbconvert, jupyter-server-terminals, jupyter-events, jupyter-server, notebook-shim, qtpy, nbclassic, qtconsole, notebook, jupyter-console, jupyter
# Successfully installed Send2Trash-1.8.2 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.6.3 jupyter-server-2.6.0 jupyter-server-terminals-0.4.4 jupyterlab-pygments-0.2.2 mistune-3.0.1 nbclassic-1.0.0 nbclient-0.8.0 nbconvert-7.6.0 nbformat-5.9.0 notebook-6.5.4 notebook-shim-0.2.3 overrides-7.3.1 pandocfilters-1.5.0 prometheus-client-0.17.0 python-json-logger-2.0.7 pyyaml-6.0 qtconsole-5.4.3 qtpy-2.3.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 terminado-0.17.1 tinycss2-1.2.1 uri-template-1.3.0 webcolors-1.13 websocket-client-1.6.0
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: jupyter_client==8.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (8.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter_client==8.2.0) (2.8.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter_client==8.2.0) (6.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter_client==8.2.0) (5.3.1)
# ...
# Requirement already satisfied: PyYAML==6 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (6.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting pyzmq==25.0.2
#   Using cached pyzmq-25.0.2-cp39-cp39-macosx_10_15_universal2.whl (1.8 MB)
# Installing collected packages: pyzmq
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 25.1.0
#     Uninstalling pyzmq-25.1.0:
#       Successfully uninstalled pyzmq-25.1.0
# Successfully installed pyzmq-25.0.2
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: qtconsole==5.4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (5.4.3)
# Requirement already satisfied: ipython-genutils in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from qtconsole==5.4.3) (0.2.0)
# Requirement already satisfied: pygments in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from qtconsole==5.4.3) (2.15.1)
# Requirement already satisfied: traitlets!=5.2.1,!=5.2.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from qtconsole==5.4.3) (5.9.0)
# Requirement already satisfied: packaging in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from qtconsole==5.4.3) (23.1)
# Requirement already satisfied: pyzmq>=17.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from qtconsole==5.4.3) (25.0.2)
# Requirement already satisfied: jupyter-core in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from qtconsole==5.4.3) (5.3.0)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from qtconsole==5.4.3) (2.3.1)
# Requirement already satisfied: ipykernel>=4.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from qtconsole==5.4.3) (6.23.0)
# Requirement already satisfied: jupyter-client>=4.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from qtconsole==5.4.3) (8.2.0)
# Requirement already satisfied: comm>=0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (0.1.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (1.5.6)
# Requirement already satisfied: ipython>=7.23.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (8.13.2)
# Requirement already satisfied: appnope in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (1.6.7)
# Requirement already satisfied: tornado>=6.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (6.3.2)
# Requirement already satisfied: psutil in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (5.9.5)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-client>=4.1->qtconsole==5.4.3) (6.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-client>=4.1->qtconsole==5.4.3) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jupyter-core->qtconsole==5.4.3) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=4.1->qtconsole==5.4.3) (3.15.0)
# Requirement already satisfied: typing-extensions in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (4.6.3)
# Requirement already satisfied: backcall in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (3.0.38)
# Requirement already satisfied: stack-data in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.6.2)
# Requirement already satisfied: decorator in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.7.5)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=4.1->qtconsole==5.4.3) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.2.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: QtPy==2.3.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (2.3.1)
# Requirement already satisfied: packaging in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from QtPy==2.3.1) (23.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: rfc3339-validator==0.1.4 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: six in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from rfc3339-validator==0.1.4) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: rfc3986-validator==0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (0.1.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: Send2Trash==1.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (1.8.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting setuptools==67.6.1
#   Using cached setuptools-67.6.1-py3-none-any.whl (1.1 MB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 58.0.4
#     Uninstalling setuptools-58.0.4:
#       Successfully uninstalled setuptools-58.0.4
# Successfully installed setuptools-67.6.1
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: six==1.16.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sniffio==1.3.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (1.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: soupsieve==2.4.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (2.4.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: stack-data==0.6.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (0.6.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data==0.6.2) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data==0.6.2) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from stack-data==0.6.2) (2.2.1)
# Requirement already satisfied: six in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data==0.6.2) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: terminado==0.17.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (0.17.1)
# Requirement already satisfied: ptyprocess in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from terminado==0.17.1) (0.7.0)
# Requirement already satisfied: tornado>=6.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from terminado==0.17.1) (6.3.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tinycss2==1.2.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (1.2.1)
# Requirement already satisfied: webencodings>=0.4 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (from tinycss2==1.2.1) (0.5.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting tornado==6.3.1
#   Using cached tornado-6.3.1-cp38-abi3-macosx_10_9_universal2.whl (424 kB)
# Installing collected packages: tornado
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.3.2
#     Uninstalling tornado-6.3.2:
#       Successfully uninstalled tornado-6.3.2
# Successfully installed tornado-6.3.1
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: traitlets==5.9.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (5.9.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: typing_extensions==4.6.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (4.6.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting uri-template==1.2.0
#   Using cached uri_template-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: uri-template
#   Attempting uninstall: uri-template
#     Found existing installation: uri-template 1.3.0
#     Uninstalling uri-template-1.3.0:
#       Successfully uninstalled uri-template-1.3.0
# Successfully installed uri-template-1.2.0
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: wcwidth==0.2.6 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (0.2.6)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: webcolors==1.13 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (1.13)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: webencodings==0.5.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (0.5.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting websocket-client==1.5.1
#   Using cached websocket_client-1.5.1-py3-none-any.whl (55 kB)
# Installing collected packages: websocket-client
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.0
#     Uninstalling websocket-client-1.6.0:
#       Successfully uninstalled websocket-client-1.6.0
# Successfully installed websocket-client-1.5.1
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting wheel==0.40.0
#   Using cached wheel-0.40.0-py3-none-any.whl (64 kB)
# Installing collected packages: wheel
# Successfully installed wheel-0.40.0
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: widgetsnbextension==4.0.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/myenv/lib/python3.9/site-packages (4.0.7)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
