# %%
! pip install anyio==3.6.2
! pip install appnope==0.1.3
! pip install argon2-cffi==21.3.0
! pip install argon2-cffi-bindings==21.2.0
! pip install arrow==1.2.3
! pip install asttokens==2.2.1
! pip install attrs==23.1.0
! pip install backcall==0.2.0
! pip install beautifulsoup4==4.12.2
! pip install bleach==6.0.0
! pip install cffi==1.15.1
! pip install comm==0.1.3
! pip install debugpy==1.6.7
! pip install decorator==5.1.1
! pip install defusedxml==0.7.1
! pip install executing==1.2.0
! pip install fastjsonschema==2.16.3
! pip install fqdn==1.5.1
! pip install idna==3.4
! pip install ipykernel==6.23.0
! pip install ipython==8.13.2
! pip install ipython-genutils==0.2.0
! pip install ipywidgets==8.0.6
! pip install isoduration==20.11.0
! pip install jedi==0.18.2
! pip install Jinja2==3.1.2
! pip install jsonpointer==2.3
! pip install jsonschema==4.17.3
! pip install jupyter==1.0.0
! pip install jupyter_client==8.2.0
! pip install jupyter-console==6.6.3
! pip install jupyter_core==5.3.0
! pip install jupyter-events==0.6.3
! pip install jupyter_server==2.5.0
! pip install jupyter_server_terminals==0.4.4
! pip install jupyterlab-pygments==0.2.2
! pip install jupyterlab-widgets==3.0.7
! pip install MarkupSafe==2.1.2
! pip install matplotlib-inline==0.1.6
! pip install mistune==2.0.5
! pip install nbclassic==1.0.0
! pip install nbclient==0.7.4
! pip install nbconvert==7.4.0
! pip install nbformat==5.8.0
! pip install nest-asyncio==1.5.6
! pip install notebook==6.5.4
! pip install notebook_shim==0.2.3
! pip install packaging==23.1
! pip install pandocfilters==1.5.0
! pip install parso==0.8.3
! pip install pexpect==4.8.0
! pip install pickleshare==0.7.5
! pip install pip==23.0.1
! pip install platformdirs==3.5.0
! pip install prometheus-client==0.16.0
! pip install prompt-toolkit==3.0.38
! pip install psutil==5.9.5
! pip install ptyprocess==0.7.0
! pip install pure-eval==0.2.2
! pip install pycparser==2.21
! pip install Pygments==2.15.1
! pip install pyrsistent==0.19.3
! pip install python-dateutil==2.8.2
! pip install python-json-logger==2.0.7
! pip install PyYAML==6
! pip install pyzmq==25.0.2
! pip install qtconsole==5.4.3
! pip install QtPy==2.3.1
! pip install rfc3339-validator==0.1.4
! pip install rfc3986-validator==0.1.1
! pip install Send2Trash==1.8.2
! pip install setuptools==67.6.1
! pip install six==1.16.0
! pip install sniffio==1.3.0
! pip install soupsieve==2.4.1
! pip install stack-data==0.6.2
! pip install terminado==0.17.1
! pip install tinycss2==1.2.1
! pip install tornado==6.3.1
! pip install traitlets==5.9.0
! pip install typing_extensions==4.6.3
! pip install uri-template==1.2.0
! pip install wcwidth==0.2.6
! pip install webcolors==1.13
! pip install webencodings==0.5.1
! pip install websocket-client==1.5.1
! pip install wheel==0.40.0
! pip install widgetsnbextension==4.0.7
# Out:
# Requirement already satisfied: anyio==3.6.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from anyio==3.6.2) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from anyio==3.6.2) (3.4)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: appnope==0.1.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.1.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: argon2-cffi==21.3.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from argon2-cffi==21.3.0) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi==21.3.0) (1.15.1)
# Requirement already satisfied: pycparser in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi==21.3.0) (2.21)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from argon2-cffi-bindings==21.2.0) (1.15.1)
# Requirement already satisfied: pycparser in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings==21.2.0) (2.21)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: arrow==1.2.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.2.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from arrow==1.2.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7.0->arrow==1.2.3) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: asttokens==2.2.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: six in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from asttokens==2.2.1) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: attrs==23.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (23.1.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: backcall==0.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.2.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: beautifulsoup4==4.12.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from beautifulsoup4==4.12.2) (2.4.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: bleach==6.0.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (6.0.0)
# Requirement already satisfied: webencodings in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from bleach==6.0.0) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from bleach==6.0.0) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: cffi==1.15.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.15.1)
# Requirement already satisfied: pycparser in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from cffi==1.15.1) (2.21)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: comm==0.1.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.1.3)
# Requirement already satisfied: traitlets>=5.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from comm==0.1.3) (5.9.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: debugpy==1.6.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.6.7)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: decorator==5.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (5.1.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: defusedxml==0.7.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.7.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: executing==1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.2.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: fastjsonschema==2.16.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (2.16.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: fqdn==1.5.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.5.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: idna==3.4 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (3.4)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ipykernel==6.23.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (6.23.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (8.2.0)
# Requirement already satisfied: nest-asyncio in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (1.5.6)
# Requirement already satisfied: pyzmq>=20 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (25.0.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (0.1.6)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (1.6.7)
# Requirement already satisfied: psutil in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (5.9.5)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (5.3.0)
# Requirement already satisfied: tornado>=6.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (6.3.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (8.13.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (5.9.0)
# Requirement already satisfied: packaging in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (23.1)
# Requirement already satisfied: comm>=0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (0.1.3)
# Requirement already satisfied: appnope in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel==6.23.0) (0.1.3)
# Requirement already satisfied: pexpect>4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (4.8.0)
# Requirement already satisfied: stack-data in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (0.6.2)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (3.0.38)
# Requirement already satisfied: backcall in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (0.2.0)
# Requirement already satisfied: decorator in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (2.15.1)
# Requirement already satisfied: pickleshare in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (0.18.2)
# Requirement already satisfied: typing-extensions in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.23.0) (4.6.3)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel==6.23.0) (6.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel==6.23.0) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.23.0) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel==6.23.0) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.23.0) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.23.0) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel==6.23.0) (0.2.6)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel==6.23.0) (1.16.0)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.23.0) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.23.0) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.23.0) (1.2.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ipython==8.13.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (8.13.2)
# Requirement already satisfied: pickleshare in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (2.15.1)
# Requirement already satisfied: typing-extensions in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (4.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (4.8.0)
# Requirement already satisfied: stack-data in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (0.6.2)
# Requirement already satisfied: appnope in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (0.1.3)
# Requirement already satisfied: traitlets>=5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (5.9.0)
# Requirement already satisfied: matplotlib-inline in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (0.18.2)
# Requirement already satisfied: backcall in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (3.0.38)
# Requirement already satisfied: decorator in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython==8.13.2) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython==8.13.2) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython==8.13.2) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.13.2) (0.2.6)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython==8.13.2) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython==8.13.2) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython==8.13.2) (2.2.1)
# Requirement already satisfied: six in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data->ipython==8.13.2) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ipython-genutils==0.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.2.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ipywidgets==8.0.6 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (8.0.6)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipywidgets==8.0.6) (5.9.0)
# Requirement already satisfied: ipython>=6.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipywidgets==8.0.6) (8.13.2)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipywidgets==8.0.6) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipywidgets==8.0.6) (3.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipywidgets==8.0.6) (6.23.0)
# Requirement already satisfied: comm>=0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (0.1.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (0.1.6)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (8.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (6.3.1)
# Requirement already satisfied: pyzmq>=20 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (25.0.2)
# Requirement already satisfied: psutil in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (5.9.5)
# Requirement already satisfied: packaging in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (23.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (5.3.0)
# Requirement already satisfied: nest-asyncio in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (1.5.6)
# Requirement already satisfied: appnope in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (3.0.38)
# Requirement already satisfied: pickleshare in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (0.7.5)
# Requirement already satisfied: backcall in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (0.2.0)
# Requirement already satisfied: typing-extensions in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (4.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (0.18.2)
# Requirement already satisfied: decorator in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (2.15.1)
# Requirement already satisfied: stack-data in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets==8.0.6) (0.6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.0.6) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.6) (2.8.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.6) (6.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==8.0.6) (3.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.0.6) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets==8.0.6) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.6) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.6) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.6) (2.2.1)
# Requirement already satisfied: six in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets==8.0.6) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.6) (3.15.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: isoduration==20.11.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (20.11.0)
# Requirement already satisfied: arrow>=0.15.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from isoduration==20.11.0) (1.2.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration==20.11.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7.0->arrow>=0.15.0->isoduration==20.11.0) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: jedi==0.18.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jedi==0.18.2) (0.8.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: Jinja2==3.1.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from Jinja2==3.1.2) (2.1.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: jsonpointer==2.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (2.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: jsonschema==4.17.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (4.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jsonschema==4.17.3) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jsonschema==4.17.3) (0.19.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: jupyter==1.0.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: ipywidgets in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter==1.0.0) (8.0.6)
# Requirement already satisfied: notebook in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter==1.0.0) (6.5.4)
# Requirement already satisfied: ipykernel in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter==1.0.0) (6.23.0)
# Requirement already satisfied: nbconvert in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter==1.0.0) (7.4.0)
# Requirement already satisfied: qtconsole in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter==1.0.0) (5.4.3)
# Requirement already satisfied: jupyter-console in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter==1.0.0) (6.6.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (8.2.0)
# Requirement already satisfied: psutil in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (5.9.5)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (1.6.7)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (5.3.0)
# Requirement already satisfied: nest-asyncio in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (1.5.6)
# Requirement already satisfied: appnope in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (0.1.3)
# Requirement already satisfied: packaging in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (23.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (0.1.6)
# Requirement already satisfied: pyzmq>=20 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (25.0.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (5.9.0)
# Requirement already satisfied: ipython>=7.23.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (8.13.2)
# Requirement already satisfied: tornado>=6.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (6.3.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipywidgets->jupyter==1.0.0) (3.0.7)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipywidgets->jupyter==1.0.0) (4.0.7)
# Requirement already satisfied: pygments in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-console->jupyter==1.0.0) (2.15.1)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-console->jupyter==1.0.0) (3.0.38)
# Requirement already satisfied: bleach in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (6.0.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (2.0.5)
# Requirement already satisfied: tinycss2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (1.2.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (6.7.0)
# Requirement already satisfied: defusedxml in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (0.7.4)
# Requirement already satisfied: jinja2>=3.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (3.1.2)
# Requirement already satisfied: nbformat>=5.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (5.8.0)
# Requirement already satisfied: beautifulsoup4 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (4.12.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (1.5.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (2.1.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (0.2.2)
# Requirement already satisfied: ipython-genutils in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (0.2.0)
# Requirement already satisfied: prometheus-client in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (0.16.0)
# Requirement already satisfied: argon2-cffi in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (1.8.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (1.0.0)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from qtconsole->jupyter==1.0.0) (2.3.1)
# Requirement already satisfied: zipp>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter==1.0.0) (3.15.0)
# Requirement already satisfied: typing-extensions in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (4.6.3)
# Requirement already satisfied: decorator in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (5.1.1)
# Requirement already satisfied: stack-data in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.7.5)
# Requirement already satisfied: backcall in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0) (3.5.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter==1.0.0) (0.2.3)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter==1.0.0) (2.5.0)
# Requirement already satisfied: jsonschema>=2.6 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert->jupyter==1.0.0) (4.17.3)
# Requirement already satisfied: fastjsonschema in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert->jupyter==1.0.0) (2.16.3)
# Requirement already satisfied: wcwidth in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0) (0.2.6)
# Requirement already satisfied: ptyprocess in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from terminado>=0.8.3->notebook->jupyter==1.0.0) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter==1.0.0) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0) (2.4.1)
# Requirement already satisfied: webencodings in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from bleach->nbconvert->jupyter==1.0.0) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from bleach->nbconvert->jupyter==1.0.0) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0) (23.1.0)
# Requirement already satisfied: anyio>=3.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (3.6.2)
# Requirement already satisfied: jupyter-events>=0.4.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (0.4.4)
# Requirement already satisfied: websocket-client in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0) (1.15.1)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (2.2.1)
# Requirement already satisfied: idna>=2.8 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (1.3.0)
# Requirement already satisfied: pycparser in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0) (2.21)
# Requirement already satisfied: pyyaml>=5.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (6.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (0.1.4)
# Requirement already satisfied: webcolors>=1.11 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0) (1.13)
# Requirement already satisfied: isoduration in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0) (2.3)
# Requirement already satisfied: fqdn in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0) (1.5.1)
# Requirement already satisfied: uri-template in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0) (1.2.0)
# Requirement already satisfied: arrow>=0.15.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0) (1.2.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: jupyter_client==8.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (8.2.0)
# Requirement already satisfied: pyzmq>=23.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter_client==8.2.0) (25.0.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter_client==8.2.0) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter_client==8.2.0) (2.8.2)
# Requirement already satisfied: tornado>=6.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter_client==8.2.0) (6.3.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter_client==8.2.0) (6.7.0)
# Requirement already satisfied: traitlets>=5.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter_client==8.2.0) (5.9.0)
# Requirement already satisfied: zipp>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter_client==8.2.0) (3.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter_client==8.2.0) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter_client==8.2.0) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: jupyter-console==6.6.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (6.6.3)
# Requirement already satisfied: ipykernel>=6.14 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-console==6.6.3) (6.23.0)
# Requirement already satisfied: pygments in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-console==6.6.3) (2.15.1)
# ...
# Requirement already satisfied: pyrsistent==0.19.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.19.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from python-dateutil==2.8.2) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: python-json-logger==2.0.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (2.0.7)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: PyYAML==6 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (6.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pyzmq==25.0.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (25.0.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: qtconsole==5.4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (5.4.3)
# Requirement already satisfied: ipython-genutils in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from qtconsole==5.4.3) (0.2.0)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from qtconsole==5.4.3) (2.3.1)
# Requirement already satisfied: traitlets!=5.2.1,!=5.2.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from qtconsole==5.4.3) (5.9.0)
# Requirement already satisfied: jupyter-client>=4.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from qtconsole==5.4.3) (8.2.0)
# Requirement already satisfied: ipykernel>=4.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from qtconsole==5.4.3) (6.23.0)
# Requirement already satisfied: packaging in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from qtconsole==5.4.3) (23.1)
# Requirement already satisfied: pygments in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from qtconsole==5.4.3) (2.15.1)
# Requirement already satisfied: pyzmq>=17.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from qtconsole==5.4.3) (25.0.2)
# Requirement already satisfied: jupyter-core in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from qtconsole==5.4.3) (5.3.0)
# Requirement already satisfied: psutil in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (5.9.5)
# Requirement already satisfied: comm>=0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (0.1.3)
# Requirement already satisfied: ipython>=7.23.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (8.13.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (6.3.1)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (1.6.7)
# Requirement already satisfied: appnope in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (0.1.3)
# Requirement already satisfied: nest-asyncio in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipykernel>=4.1->qtconsole==5.4.3) (1.5.6)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-client>=4.1->qtconsole==5.4.3) (6.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-client>=4.1->qtconsole==5.4.3) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jupyter-core->qtconsole==5.4.3) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=4.1->qtconsole==5.4.3) (3.15.0)
# Requirement already satisfied: pickleshare in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.7.5)
# Requirement already satisfied: backcall in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (3.0.38)
# Requirement already satisfied: decorator in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (5.1.1)
# Requirement already satisfied: typing-extensions in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (4.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (4.8.0)
# Requirement already satisfied: stack-data in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.18.2)
# Requirement already satisfied: six>=1.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=4.1->qtconsole==5.4.3) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.2.6)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=4.1->qtconsole==5.4.3) (1.2.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: QtPy==2.3.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (2.3.1)
# Requirement already satisfied: packaging in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from QtPy==2.3.1) (23.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: rfc3339-validator==0.1.4 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: six in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from rfc3339-validator==0.1.4) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: rfc3986-validator==0.1.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.1.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: Send2Trash==1.8.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.8.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: setuptools==67.6.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (67.6.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: six==1.16.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sniffio==1.3.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: soupsieve==2.4.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (2.4.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: stack-data==0.6.2 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.6.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data==0.6.2) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data==0.6.2) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from stack-data==0.6.2) (0.2.2)
# Requirement already satisfied: six in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data==0.6.2) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: terminado==0.17.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.17.1)
# Requirement already satisfied: tornado>=6.1.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from terminado==0.17.1) (6.3.1)
# Requirement already satisfied: ptyprocess in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from terminado==0.17.1) (0.7.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tinycss2==1.2.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.2.1)
# Requirement already satisfied: webencodings>=0.4 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (from tinycss2==1.2.1) (0.5.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tornado==6.3.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (6.3.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: traitlets==5.9.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (5.9.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: typing_extensions==4.6.3 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (4.6.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: uri-template==1.2.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.2.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: wcwidth==0.2.6 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.2.6)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: webcolors==1.13 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.13)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: webencodings==0.5.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.5.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: websocket-client==1.5.1 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (1.5.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: wheel==0.40.0 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (0.40.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: widgetsnbextension==4.0.7 in /Users/macintosh/Desktop/data_engineering_Esentials_using/.venv/lib/python3.9/site-packages (4.0.7)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
